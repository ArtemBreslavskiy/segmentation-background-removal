# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent.parent.parent
sys.path.append(str(project_root))

from src.utils.visualization.visualization import visualization
from paths.__init__ import path
import yaml

# %%
with open(path.CONFIG) as f:
    config = yaml.safe_load(f)

dict_path = path.SAVED_DICT / f"{config['model_name']}_best.pt"
visualization(dict_path)
