# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent.parent.parent
sys.path.append(str(project_root))

import yaml
from paths.ProjectPaths import ProjectPaths

from src.utils.visualization.visualization import visualization

# %%
path = ProjectPaths()
with open(path.CONFIG) as f:
    config = yaml.safe_load(f)

checkpoints_path = path.SAVED_CHECKPOINTS / f"{config['model']['model_name']}_best.pt"
tests_path = path.SAVED_BEST_MODEL_TESTS
visualization(checkpoints_path, tests_path)
